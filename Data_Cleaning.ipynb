# %% [markdown]
# # Data Cleaning - Superstore Sales Data

# %% [markdown]
# * Importing Required Libraries

# %%
import pandas as pd

# %% [markdown]
# * Load the file

# %%
df = pd.read_excel("Superstore.xls")

# %% [markdown]
# * Reviewing Data Structure

# %%
df.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2       3  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3       4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4       5  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %% [markdown]
# * Dropping Unwanted Columns

# %%
drop = [
    'Row ID', 'Customer Name', 'Ship Mode', 'Postal Code', 'Product Name'
    ]

df.drop(columns=drop, inplace=True)

# %%
df.head(10)
# Out:
#          Order ID Order Date  Ship Date Customer ID    Segment Country/Region  \
# 0  CA-2020-152156 2020-11-08 2020-11-11    CG-12520   Consumer  United States
# 1  CA-2020-152156 2020-11-08 2020-11-11    CG-12520   Consumer  United States
# 2  CA-2020-138688 2020-06-12 2020-06-16    DV-13045  Corporate  United States
# 3  US-2019-108966 2019-10-11 2019-10-18    SO-20335   Consumer  United States
# 4  US-2019-108966 2019-10-11 2019-10-18    SO-20335   Consumer  United States
# 5  CA-2018-115812 2018-06-09 2018-06-14    BH-11710   Consumer  United States
# 6  CA-2018-115812 2018-06-09 2018-06-14    BH-11710   Consumer  United States
# 7  CA-2018-115812 2018-06-09 2018-06-14    BH-11710   Consumer  United States
# 8  CA-2018-115812 2018-06-09 2018-06-14    BH-11710   Consumer  United States
# 9  CA-2018-115812 2018-06-09 2018-06-14    BH-11710   Consumer  United States
#
#               City       State Region       Product ID         Category  \
# ...

# %%
df.isnull().sum()
# Out:
# Order ID          0
# Order Date        0
# Ship Date         0
# Customer ID       0
# Segment           0
# Country/Region    0
# City              0
# State             0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %% [markdown]
# * Finding Duplicate values

# %%
duplicates = df[df.duplicated()]
print(f"Number of duplicated rows: {duplicates.shape[0]}")
duplicates
# Out:
# Number of duplicated rows: 1
#             Order ID Order Date  Ship Date Customer ID      Segment  \
# 3406  US-2018-150119 2018-04-23 2018-04-27    LB-16795  Home Office
#
#      Country/Region      City State Region       Product ID   Category  \
# 3406  United States  Columbus  Ohio   East  FUR-CH-10002965  Furniture
#
#      Sub-Category    Sales  Quantity  Discount   Profit
# 3406       Chairs  281.372         2       0.3 -12.0588

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (9993, 16)

# %% [markdown]
# * Converting Date Columns

# %%
df['order_date'] = pd.to_datetime(df['Order Date'])
df['ship_date'] = pd.to_datetime(df['Ship Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 0 to 9993
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        9993 non-null   object
#  1   Order Date      9993 non-null   datetime64[ns]
#  2   Ship Date       9993 non-null   datetime64[ns]
#  3   Customer ID     9993 non-null   object
#  4   Segment         9993 non-null   object
#  5   Country/Region  9993 non-null   object
#  6   City            9993 non-null   object
#  7   State           9993 non-null   object
#  8   Region          9993 non-null   object
#  9   Product ID      9993 non-null   object
#  10  Category        9993 non-null   object
#  11  Sub-Category    9993 non-null   object
#  12  Sales           9993 non-null   float64
#  13  Quantity        9993 non-null   int64
#  14  Discount        9993 non-null   float64
#  15  Profit          9993 non-null   float64
# ...

# %% [markdown]
# * Extracting Year-Month Column

# %%
df['Year-Month'] = df['order_date'].dt.to_period('M').astype(str)

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Customer ID', 'Segment',
#        'Country/Region', 'City', 'State', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit', 'order_date',
#        'ship_date', 'Year-Month'],
#       dtype='object')

# %%
df.head(5)
# Out:
#          Order ID Order Date  Ship Date Customer ID    Segment Country/Region  \
# 0  CA-2020-152156 2020-11-08 2020-11-11    CG-12520   Consumer  United States
# 1  CA-2020-152156 2020-11-08 2020-11-11    CG-12520   Consumer  United States
# 2  CA-2020-138688 2020-06-12 2020-06-16    DV-13045  Corporate  United States
# 3  US-2019-108966 2019-10-11 2019-10-18    SO-20335   Consumer  United States
# 4  US-2019-108966 2019-10-11 2019-10-18    SO-20335   Consumer  United States
#
#               City       State Region       Product ID         Category  \
# 0        Henderson    Kentucky  South  FUR-BO-10001798        Furniture
# 1        Henderson    Kentucky  South  FUR-CH-10000454        Furniture
# 2      Los Angeles  California   West  OFF-LA-10000240  Office Supplies
# 3  Fort Lauderdale     Florida  South  FUR-TA-10000577        Furniture
# 4  Fort Lauderdale     Florida  South  OFF-ST-10000760  Office Supplies
#
# ...

# %% [markdown]
# * Saving Cleaned Dataset

# %%
df.to_csv('cleaned_superstore_data.csv', index=False)
